# %% [markdown]
# #### Parte 0 - Funcoes auxiliares para o projeto

# %%
# %pylab
# %matplotlib inline
# Out:
# Using matplotlib backend: Qt4Agg
# Populating the interactive namespace from numpy and matplotlib

# %%
def linearSolve(a, b):
    '''
        Resolve um sistema linear utilizando o metodo de
        diagonalizacao da matriz (fatoracao de Gauss) seguido da
        resolucao do sistema triangular superior.
        
        IMPORTANTE (1): Idealmente, trabalhe com floats (coloca um '.' dps do numero inteiro.)
        IMPORTANTE(2): a e b sao arrays, nao listas.
    '''
    
    # Diagonaliza a matriz a
    for i in range(a.shape[0]-1):
        max = i+ np.argmax(np.absolute(a[i:, i]))
        
        a[[i,max]] = a[[max,i]] # Troca linhas da array (magic!)
        b[[i,max]] = b[[max,i]]

        for j in range(i+1, a.shape[0]):
            m = a[j,i]/(float)(a[i,i])
            a[j] = a[j] - (m*a[i]) # Usar -= da um warning (nao sei o porque)
            b[j] = b[j] - (m*b[i])
      
    x = np.empty(b.shape)
    for i in np.arange(a.shape[0]-1, -1, -1):
        x[i] = b[i]
        for j in np.arange(a.shape[0]-1, i, -1):
            x[i] -= (a[i, j] * x[j])
        x[i] /= (float)(a[i,i])
    return x

# %%
# Teste da funcao linearsolve().
# Faca mais testes pra ver se encontra bugs 
a = np.array([[.3e33,1., .5e4], [1.,2., .5e4],[3.5, 4., .5e-4]])
b = np.array([9. ,8., .1])

x = linearSolve(a, b)
print x
print "testando solucao..."
if np.allclose(np.dot(a, x), b):
    print "Sistema resolvido corretamente."
else:
    print "Resposta esperada:", np.linalg.solve(a, b)
# Out:
# [  3.41666660e-33   2.49999801e-02   1.59000001e-03]
# testando solucao...
# Sistema resolvido corretamente.

# %%
def gaussSeidel(a, b, k_max=1000000, tolerancia=1e-5):
    '''
        Resolve um sistema linear utilizando o metodo de
        Gauss-Seidel.
        
        IMPORTANTE (1): Idealmente, trabalhe com floats (coloca um '.' dps do numero inteiro.)
        IMPORTANTE (2): a e b sao arrays, nao listas.
        IMPORTANTE (3): A resposta pode divergir. Teste a matriz pelo criterio de Sassefeld para ter certeza.
    '''
    
    x = np.ones(len(b)) #Define chute inicial (tudo 1)            , dtype ='float128'
    k = 0 #Contagem de iteracoes
    erro = tolerancia+1 #Define erro
    
    while k < k_max and erro > tolerancia:
        x_0 = np.copy(x) #Copia para verificacao do erro relativo
        
        
        #Atualiza os elementos de x
        for i in range(len(x)):
            x[i] = b[i]
            for j in range(len(x)):
                if i != j:
                    x[i] -= (a[i,j] * x[j])
            x[i] /= a[i,i]
        
        #Atualiza o num de iteracoes e o erro
        k+=1
        erro = np.max(np.absolute(np.subtract(x,x_0))) / np.max(np.absolute(x))
    
    return x

# %%
# Teste da funcao linearsolve().
# Faca mais testes pra ver se encontra bugs 
a = np.array([[2., 1.],[3., 4.]])
b = np.array([1., -1.])

x = gaussSeidel(a, b)
print x
print "testando solucao..."
if np.allclose(np.dot(a, x), b):
    print "Sistema resolvido corretamente."
else:
    print "Resposta esperada:", np.linalg.solve(a, b)
# Out:
# [ 0.9999971  -0.99999782]
# testando solucao...
# Sistema resolvido corretamente.

# %% [markdown]
# # Parte 1 - Cantareira

# %% [markdown]
# Nessa parte, analizaremos dados do nível de água da usina Cantareira entre os anos de 2003 e agosto de 2015.
#
# O proposto é utilizar métodos numéricos para ajustar os dados a uma função apropriada.

# %%
# Cria estrutura para armazenar datas e niveis da usina cantareira
cantareira = {"datas": [], "dia": [], "niveis": []}
datas = cantareira["datas"]
dia = cantareira["dia"]
niveis = cantareira["niveis"]

# %%
#Formata os dados lidos do arquivo como duas listas
with open('cantareira.txt', 'r') as file:
    i = 1
    for line in file:
        atual = line.split()
        datas.append(int(atual[0]))
        dia.append(i)
        niveis.append(float(atual[1]))
        i+=1

# %%
datasArray = np.array(datas, dtype='float64')
diaArray = np.array(dia, dtype='float64')
niveisArray = np.array(niveis, dtype='float64')

# %%
print "datas\t\t","dia\t", "niveis"
for i in range(len(datas)):
    print datas[i],"\t",dia[i], "\t", niveis[i]
# Out:
# datas		dia	niveis
# 20030101 	1 	42.5
# 20030102 	2 	42.3
# 20030103 	3 	42.3
# 20030104 	4 	42.3
# 20030105 	5 	42.4
# 20030106 	6 	42.4
# 20030107 	7 	42.5
# 20030108 	8 	42.5
# 20030109 	9 	42.6
# 20030110 	10 	42.3
# 20030111 	11 	42.4
# 20030112 	12 	42.6
# 20030113 	13 	43.0
# 20030114 	14 	42.9
# 20030115 	15 	42.8
# 20030116 	16 	42.8
# 20030117 	17 	43.3
# 20030118 	18 	44.6
# 20030119 	19 	45.3
# 20030120 	20 	46.1
# 20030121 	21 	46.7
# 20030122 	22 	48.1
# 20030123 	23 	49.2
# 20030124 	24 	50.1
# 20030125 	25 	51.1
# 20030126 	26 	52.1
# 20030127 	27 	53.3
# 20030128 	28 	54.4
# 20030129 	29 	56.0
# 20030130 	30 	57.5
# 20030131 	31 	59.1
# 20030201 	32 	60.4
# 20030202 	33 	61.1
# 20030203 	34 	61.5
# 20030204 	35 	61.9
# 20030205 	36 	62.1
# 20030206 	37 	62.6
# 20030207 	38 	62.9
# 20030208 	39 	63.0
# 20030209 	40 	63.2
# 20030210 	41 	63.3
# 20030211 	42 	63.4
# 20030212 	43 	63.4
# 20030213 	44 	63.2
# 20030214 	45 	63.6
# 20030215 	46 	63.6
# 20030216 	47 	63.8
# ...

# %%
plt.plot(dia, niveis, 'g-')
plt.title("Nivel da Usina Cantareira entre 2003 e 2015")
plt.ylabel('nivel da usina')
plt.xlabel("dia")
plt.show()

# %% [markdown]
# ## Aproximações para a a tabela por mínimos quadrados

# %%
def residuoMMQ(f, x, y):
    '''
        Calcula o residuo (soma dos quadrados dos erros) da aprox f de y nos pontos x.
    '''
    
    soma = 0
    for xk, yk in zip(x,y):
        soma += pow(f(xk) - yk, 2)
    return soma

# %% [markdown]
# ### Função linear

# %% [markdown]
# Aproximaremos a tabela acima por uma função no modelo
# $$f(x) = a \cdot g_1(x) + b \cdot g_2(x),$$
# com $g_1(x) = x$ e $g_2(x) = 1$.
# Para descobrir os coeficientes, temos que
# $$L(a, b) = \sum\limits_{k=1}^m (f(x_k) - y_k)^2$$
# tem que ser mínima. para isso, $\frac{\partial L(a)}{\partial a} = 0$ e $\frac{\partial L(b)}{\partial b} = 0$. Assim, teremos que resolver um sistema de equações no formato:
#
# $$\sum\limits_{k=1}^m x_k^2 \cdot a + \sum\limits_{k=1}^m x_k \cdot b = \sum\limits_{k=1}^m (x_k \cdot y_k) $$
# $$\sum\limits_{k=1}^m x_k \cdot a + \sum\limits_{k=1}^m 1 \cdot b = \sum\limits_{k=1}^m (1 \cdot y_k) $$

# %%
def linearMMQ(x, y):
    '''
        Aproxima pontos dados numa funcao linear pelo metodo dos minimos quadrados.
    '''
    # Ajustando os coeficientes das matrizes A e B
    somaX = np.sum(x)
    somaQuadradoX = np.sum(np.square(x))
    somaY = np.sum(y)
    somaXY = np.sum(np.multiply(x, y))
    num = len(y)

    a = np.array([[somaQuadradoX, somaX],
                  [somaX, num]])
    b = np.array([somaXY, somaY])
    print "Resolvendo o sistema linear A * c = B:"
    print "A =", a
    print "B =", b
    
    c = linearSolve(a, b)
    
    print "testando solucao..."
    if np.allclose(np.dot(a, c), b):
        print "Sistema resolvido corretamente."
    else:
        print "Resposta esperada:", np.linalg.solve(a, b)
    return c

# %%
c1 = linearMMQ(diaArray, niveisArray)
# Out:
# Resolvendo o sistema linear A * c = B:
# A = [[  3.28170435e+10   1.06606530e+07]
#  [  1.06606530e+07   4.61700000e+03]]
# B = [  5.60840466e+08   2.44031300e+05]
# testando solucao...
# Sistema resolvido corretamente.

# %%
aproxLin = lambda x: c1[0]*x + c1[1] #funcao linear encontrada

linearY = np.vectorize(aproxLin)(dia)

plt.plot(dia, niveis, 'b-')
plt.plot(dia, linearY, 'r-')
plt.title("Nivel da Usina Cantareira entre 2003 e 2015")
plt.ylabel('nivel da usina')
plt.xlabel("dia")
plt.show()
print "O residuo encontrado na aproximacao foi:",residuoMMQ(aproxLin, dia, niveis)
# Out:
# O residuo encontrado na aproximacao foi: 2736075.73591

# %% [markdown]
# Note que a aproximação considerada não foi satisfatória, já que não se pode avaliar bem o comportamento da usina com base na reta encontrada, e o resíduo foi muito grande.

# %% [markdown]
# ### Função de 4o grau

# %% [markdown]
# Para fazer a aproximação, seguimos o mesmo processo da etapa linear, mas considerando o modelo
#
#
# $$f(x) = a \cdot g_1(x) + b \cdot g_2(x) + c \cdot g_3(x) + d \cdot g_4(x) + e \cdot g_5(x),$$
#
#
# com $g_1(x) = x^4$, $g_2(x) = x^3$, $g_3(x) = x^2$, $g_4(x) = x$ e $g_5(x) = 1$.
# Dessa forma, chegamos no sistema:
#
#
# $$\sum\limits_{k=1}^m x_k^8 \cdot a + \sum\limits_{k=1}^m x_k^7 \cdot b + \sum\limits_{k=1}^m x_k^6 \cdot c + \sum\limits_{k=1}^m x_k^5 \cdot d + \sum\limits_{k=1}^m x_k^4 \cdot e= \sum\limits_{k=1}^m (x_k^4 \cdot y_k) $$
# $$\sum\limits_{k=1}^m x_k^7 \cdot a + \sum\limits_{k=1}^m x_k^6 \cdot b + \sum\limits_{k=1}^m x_k^5 \cdot c + \sum\limits_{k=1}^m x_k^4 \cdot d + \sum\limits_{k=1}^m x_k^3 \cdot e= \sum\limits_{k=1}^m (x_k^3 \cdot y_k) $$
# $$\sum\limits_{k=1}^m x_k^6 \cdot a + \sum\limits_{k=1}^m x_k^5 \cdot b + \sum\limits_{k=1}^m x_k^4 \cdot c + \sum\limits_{k=1}^m x_k^3 \cdot d + \sum\limits_{k=1}^m x_k^2 \cdot e= \sum\limits_{k=1}^m (x_k^2 \cdot y_k) $$
# $$\sum\limits_{k=1}^m x_k^5 \cdot a + \sum\limits_{k=1}^m x_k^4 \cdot b + \sum\limits_{k=1}^m x_k^3 \cdot c + \sum\limits_{k=1}^m x_k^2 \cdot d + \sum\limits_{k=1}^m x_k \cdot e= \sum\limits_{k=1}^m (x_k \cdot y_k) $$
# $$\sum\limits_{k=1}^m x_k^4 \cdot a + \sum\limits_{k=1}^m x_k^3 \cdot b + \sum\limits_{k=1}^m x_k^2 \cdot c + \sum\limits_{k=1}^m x_k \cdot d + \sum\limits_{k=1}^m 1 \cdot e= \sum\limits_{k=1}^m (1 \cdot y_k) $$

# %%
def quartoGrauMMQ(x, y):
    '''
        Aproxima pontos dados numa funcao polinomial de 4o grau pelo metodo dos minimos quadrados.
    '''
    somaPotX = []
    for i in range(9):
        sum = 0 #Pode ser reduzida para somaPotX.append(np.sum(x**i)) se nao houver overflow
        for xk in x:
            sum += pow(xk, i)
        somaPotX.append(sum)
        
    somaPotXY = []
    for i in range(5): 
        soma = 0 #Pode ser reduzida para somaPotXY.append(np.sum(np.multiply(x**i, y))) se nao houver overflow
        for xk, yk in zip(x,y):
            soma += (pow(xk, i)*yk)
        somaPotXY.append(soma)
    
    # Ajustando os coeficientes das matrizes A e B
    a = np.array(
        [[somaPotX[8], somaPotX[7], somaPotX[6], somaPotX[5], somaPotX[4]],
         [somaPotX[7], somaPotX[6], somaPotX[5], somaPotX[4], somaPotX[3]],
         [somaPotX[6], somaPotX[5], somaPotX[4], somaPotX[3], somaPotX[2]],
         [somaPotX[5], somaPotX[4], somaPotX[3], somaPotX[2], somaPotX[1]],
         [somaPotX[4], somaPotX[3], somaPotX[2], somaPotX[1], somaPotX[0]]])
         
    b = np.array(somaPotXY[::-1]) #B eh a array somaPotXY de baixo pra cima
    
    print "Resolvendo o sistema linear A * c = B:"
    print "A =", a
    print "B =", b
    
    c = linearSolve(a, b)
    
    #testando a solucao
    print "testando solucao..."
    if np.allclose(np.dot(a, c), b):
        print "Sistema resolvido corretamente."
    else:
        print "Resposta esperada:", np.linalg.solve(a, b)
    return c

# %%
c4 = quartoGrauMMQ(diaArray, niveisArray)
print c4
# Out:
# Resolvendo o sistema linear A * c = B:
# A = [[  1.06027755e+32   2.58324263e+28   6.39367053e+24   1.61543746e+21
#     4.19821329e+17]
#  [  2.58324263e+28   6.39367053e+24   1.61543746e+21   4.19821329e+17
#     1.13649522e+14]
#  [  6.39367053e+24   1.61543746e+21   4.19821329e+17   1.13649522e+14
#     3.28170435e+10]
#  [  1.61543746e+21   4.19821329e+17   1.13649522e+14   3.28170435e+10
#     1.06606530e+07]
#  [  4.19821329e+17   1.13649522e+14   3.28170435e+10   1.06606530e+07
#     4.61700000e+03]]
# B = [  1.67029416e+19   5.02689483e+15   1.60327035e+12   5.60840466e+08
#    2.44031300e+05]
# testando solucao...
# Sistema resolvido corretamente.
# [  1.81945642e-12  -2.33375355e-08   8.49240250e-05  -8.79321350e-02
#    6.12828699e+01]

# %%
aprox4o = lambda x: c4[0]*x**4 + c4[1]*x**3 + c4[2]*x**2 + c4[3]*x**1 + c4[4] #funcao linear encontrada

quartoGrauY = np.vectorize(aprox4o)(dia)

plt.plot(dia, niveis, 'b-')
plt.plot(dia, quartoGrauY, 'r-')
plt.title("Nivel da Usina Cantareira entre 2003 e 2015")
plt.ylabel('nivel da usina')
plt.xlabel("dia")
plt.show()
print "O residuo encontrado na aproximacao foi:",residuoMMQ(aprox4o, dia, niveis)
# Out:
# O residuo encontrado na aproximacao foi: 765031.452239

# %% [markdown]
# Nesse caso, a aproximação se mostrou razoável para acompanhar o comportamento da usina, mas ignorou as mudanças bruscas em seu nível.

# %% [markdown]
# ### Função polinomial de grau arbitrário

# %% [markdown]
# Para testar outras aproximações, foi desenvolvida um método que modela pontos a uma função polinomial de grau arbitrário, e verificou-se qual grau que fornece a melhor aproximação. Note que, em teoria, quanto maior o grau maior a precisão dos pontos, No entanto, isso não é necessariamente verdade na prática, já que pode haver perda de precisão ao tratar-se altas potências como é o caso:

# %%
def grauX_MMQ(x, y, grau=4, verborragic=True):
    '''
        Aproxima pontos dados numa funcao polinomial de grau arbitrário pelo metodo dos minimos quadrados.
        A precisão depende da máquina, sendo seu "BottleNeck" a implementacao do NumPy - que por sua vez facilitou
        bastante a implementacao.
    '''
    somaPotX = []
    for i in range(grau*2+1):
        sum = 0 #Pode ser reduzida para somaPotX.append(np.sum(x**i)) se nao houver overflow
        for xk in x:
            sum += pow(xk, i)
        somaPotX.append(sum)
        
    somaPotXY = []
    for i in range(grau+1): 
        soma = 0 #Pode ser reduzida para somaPotXY.append(np.sum(np.multiply(x**i, y))) se nao houver overflow
        for xk, yk in zip(x,y):
            soma += (pow(xk, i)*yk)
        somaPotXY.append(soma)
    
    # Ajustando os coeficientes das matrizes A e B
    a = np.array([[somaPotX[j] for j in range (2*grau - i, grau-i-1, -1)] for i in range (grau+1)])
         
    b = np.array(somaPotXY[::-1]) #B eh a array somaPotXY de baixo pra cima
    
    if verborragic:
        print "Resolvendo o sistema linear A * c = B:"
        print "A =", a
        print "B =", b
    
    c = linearSolve(a, b)
    
    if verborragic:
        #testando a solucao
        print "testando solucao..."
        if np.allclose(np.dot(a, c), b):
            print "Sistema resolvido corretamente."
        else:
            print "Resposta esperada:", np.linalg.solve(a, b)
    return c

# %%
def aproxGrauX(x, y, grau=4):
    c = grauX_MMQ(x, y, grau, verborragic=False)
    return lambda x: np.sum([c[j]*x**(grau-j) for j in range(grau+1)])

# %%
menorRes = 100000000000000.
menorInd = -1
for i in range (15, 30):
    aprox = aproxGrauX(diaArray,niveisArray, grau=i)
    residuo = residuoMMQ(aprox, dia, niveis)
    print "indice", i , "Residuo:", residuo
    if residuo < menorRes:
        menorRes = residuo
        menorInd = i
print "Menor residuo:", menorRes, "Indice:", menorInd
# Out:
# indice 15 Residuo: 296515.29565
# indice 16 Residuo: 286550.425011
# indice 17 Residuo: 280330.407986
# indice 18 Residuo: 281043.163329
# indice 19 Residuo: 276162.670042
# indice 20 Residuo: 276931.501521
# indice 21 Residuo: 292428.485971
# indice 22 Residuo: 281423.86412
# indice 23 Residuo: 387603.576239
# indice 24 Residuo: 277073.718011
# indice 25 Residuo: 279772.131459
# indice 26 Residuo: 278187.77461
# indice 27 Residuo: 288433.555997
# indice 28 Residuo: 279055.237748
# indice 29 Residuo: 450224.527335
# Menor residuo: 276162.670042 Indice: 19

# %%
#Testando com o menor indice, 19
c19 = grauX_MMQ(diaArray, niveisArray, 19, verborragic=False)
print c19
# Out:
# [ -9.50424713e-63   1.92016371e-58  -1.22159037e-54   7.72700736e-53
#    2.82225553e-47  -8.19915141e-44   3.52641573e-41  -1.66613465e-36
#    1.34109901e-32  -2.98493895e-29  -1.76983112e-26   4.22683896e-23
#    9.37520045e-19  -4.55325844e-15   9.97224933e-12  -1.22247259e-08
#    8.34447702e-06  -2.74999829e-03   2.68771500e-01   5.25499738e+01]

# %%
aprox19o = lambda x: np.sum([c19[j]*x**(19-j) for j in range(20)])
grau19Y = np.vectorize(aprox19o)(dia)

plt.plot(dia, niveis, 'b-')
plt.plot(dia, grau19Y , 'r-')
plt.title("Nivel da Usina Cantareira entre 2003 e 2015, e a melhor aproximacao encontrada")
plt.ylabel('nivel da usina')
plt.xlabel("dia")
plt.show()
print "O residuo encontrado na aproximacao foi:",residuoMMQ(aprox19o, dia, niveis)
# Out:
# O residuo encontrado na aproximacao foi: 276162.670042

# %% [markdown]
# ## Análise da utilização do volume morto

# %% [markdown]
# Vamos explorar os dados a partir do ano de 2013:

# %%
inicio = datas.index(20130101)

plt.plot(dia[inicio:], niveis[inicio:], 'b-')
plt.title("Nivel da Usina Cantareira entre 2013 e 2015")
plt.ylabel('nivel da usina')
plt.xlabel("dia")
plt.show()

# %% [markdown]
# Note que no ano de 2014 foi utilizada a maior cota de volume morto no sistema Cantareira. A seguir, vamos pegar os dados até antes do momento da utilização desse volume, e ajustaremos um polinômio de grau 4 a esse valor.

# %%
fim = inicio + np.argmin(niveis[inicio:4200])

print "o volume morto foi utilizado apos", datas[fim]

aprox = aproxGrauX(diaArray[inicio:fim], niveisArray[inicio:fim], grau=4)

aproxY = np.vectorize(aprox)(dia)

plt.plot(dia[inicio:fim], niveis[inicio:fim], 'b-')
plt.plot(dia[inicio:fim], aproxY[inicio:fim] , 'r-')
plt.title("Nivel da Usina Cantareira entre 2013 e a maior utilizacao de volume morto em 2014")
plt.ylabel('nivel da usina')
plt.xlabel("dia")
plt.show()
# Out:
# o volume morto foi utilizado apos 20140515

# %% [markdown]
# Verificaremos agora em quanto tempo a usina chegaria a 0% caso não fosse utilizada a cota de volume morto, de acordo com nossa aproximação:

# %%
indexDaSeca = np.argmin(np.absolute(aproxY))
print "Usina passaria de ", aproxY[indexDaSeca-1], "a", aproxY[indexDaSeca], "(chegaria a zero) no dia", \
datas[indexDaSeca], "se nao houvesse a primeira \nutilizacao de volume morto de 2014."
# Out:
# Usina passaria de  0.052764033433 a -0.04490519315 (chegaria a zero) no dia 20140815 se nao houvesse a primeira
# utilizacao de volume morto de 2014.

# %% [markdown]
# Agora, analisaremos quando a represa chegaria a 0% caso não fosse colocada a segunda cota de volume morto de 2014:

# %%
inicio2 = 4200
fim2 = inicio2 + np.argmin(niveis[4200:4400])

aproxLinear = aproxGrauX(diaArray[inicio2:fim2], niveisArray[inicio2:fim2], grau=2)
print residuoMMQ(aproxLinear, diaArray[inicio2:fim2], niveisArray[inicio2:fim2])

aproxLinearY = np.vectorize(aproxLinear)(dia)

plt.plot(dia[inicio2:fim2], niveis[inicio2:fim2], 'b-')
plt.plot(dia[inicio2:fim2], aproxLinearY[inicio2:fim2] , 'r-')
plt.title("Nivel da Usina Cantareira entre julho e a segunda utilizacao de volume morto de 2014")
plt.ylabel('nivel da usina')
plt.xlabel("dia")
plt.show()
# Out:
# 3.03064599393

# %%
indexDaSeca2 = np.argmin(np.absolute(aproxLinearY))
print "Usina passaria de ", aproxLinearY[indexDaSeca2-1], "a", aproxLinearY[indexDaSeca2], "(chegaria a zero) no dia",\
datas[indexDaSeca2], "se nao houvesse a segunda \nutilizacao de volume morto de 2014."
# Out:
# Usina passaria de  0.0745315374752 a -0.0715968974986 (chegaria a zero) no dia 20141115 se nao houvesse a segunda
# utilizacao de volume morto de 2014.

# %% [markdown]
# # Parte 2 - Equação de Calor
#
# Nesta etapa, vamos resolver uma equação diferencial parcial através dos Métodos das Diferenças Finitas. Mais especificamente, trabalharemos com uma equação do calor, que modela a temperatura de uma barra afetada por uma fonte de calor, utiliza duas variáveis, tempo e espaço. Assim, pode ser demonstrado que a função u(x, t) deve ser solução da seguinte equação diferencial
#
#                                     ∂u/∂t (x, t) = γ∂²u/∂x²(x, t) + ψ(x, t)
#
# onde γ é o coeficiente de condução de calor e ψ(x, t) é uma função que representa a fonte de calor. Além disso, devemos impor condições iniciais e de contorno sobre o problema.
#
#                                                 u(x, 0) = f(x)
#                                                 u(0, t) = p(t)
#                                                 u(L, t) = q(t).
#
# Este tipo de condição inicial dado é chamado de Condição de Dirichlet. Se, por exemplo, um dos lados da barra estiver isolado e não conduzir calor, trocaremos a condição de contorno correspondente por uma condição do tipo ux(x, t) = 0 (ux é a derivada de u(x, t) com relação a x), chamada de Condição de Neumann. Uma maneira simples de se resolver problemas deste tipo é usando um esquema de diferenças finitas, fazendo discretizações no tempo e no espaço [5]. Para isto, usaremos
#
#                                                 u(xi, tn) ≈ u(n,i).
#
# ________________________________________________________________________________________________________________________________
#
# Para aproximar a derivada temporal usando diferenças avançadas, fazemos
#
#                                             ut(xi, tj ) ≈ u(j+1 i) − u(j,i)/k, (2)
#
# onde k é o passo associado à variável temporal, e j = 0, 1, . . . .
# Agora, a derivada espacial será sempre aproximada por
#
#                                 uxx(xi, tj ) ≈ u(j, i+1) − 2u (j, i) + u(j, i−1)/h², (3)
#
# onde h é tal que xı = ıh, para ı = 0, 1, . . . , m, sendo m um inteiro positivo.
# Assim, podemos substituir (3) e (2) em (1) e obter
#
#                         u(j+1, i) − u(j, i)/k = γu(j, i+1) − 2u(j, i) + u(j, i−1)/h² + ψ(j, i)
#
# Podemos, então, explicitar
#                                                           u(j+1, i)
#
# em termo das outras variáveis, encontrando
#
#         u(j+1, i) = (1 − 2kγ/h²) u(j, i) + γk/h² . (u(j, i+1) + u(j, i−1)) + kψ(j, i), i = 1, . . . , m, j > 0 (4)
#
# Simplificando em forma matricial, temos
#
#                                                       u(j+1) = Au(j) + kψ(j)
#
# Em que A é a matriz tridiagonal de diagonais (lambda, 1 - 2 . lambda, lambda), com (lambda = γk/h²).
# Essa é a fórmula que usaremos abaixo no método das diferenças avançadas.
#
# ________________________________________________________________________________________________________________________________
#
# Para aproximar a derivada temporal usando diferenças atrasadas, fazemos
#
#                                             ut(xi, tj ) ≈ u(j, i) − u(j−1, i)/k, (5)
#
# Substituindo (3) e (5) em (1), temos
#
#                             u(j, i) − u(j−1, i)/k = γu(j, i+1) − 2u(j, i) + u(j, i−1)/h² + ψ(j, i)
#
# Podemos, então, isolar
#
#                                                           u(j−1, i)
#
# e escrevê-la em termo das outras variáveis, encontrando
#
#         u(j−1, i) + kψ(j, i) = −γk/h²2 . u(j, i−1) + (1 + 2kγ/h²) u(j, i) − γk/h² . u(j, i+1), i = 1, . . . , m, j > 0 (6)
#
# Simplificando em forma matricial, temos
#
#                                                       Au(j+1) = u(j) + kψ(j)
#
# Em que A é a matriz tridiagonal de diagonais (lambda, 1 - 2 . lambda, lambda), com (lambda = γk/h²).
# Essa é a fórmula que usaremos abaixo no método das diferenças avançadas.

# %% [markdown]
# #Método da Diferenças Finitas Avançadas
#
# Este método utiliza uma multiplicação matricial para encontrar o novo veotor u(j+1) a partir de um vetor u(j). Utilizamos a função de multiplicação matricial do NumPy para este processo. A função base foi fixada por conveniência, mas todos os outros parâmetros são recebidos na entrada
#
# Note que quando o lambda (gamma.k/h²) é maior que 1/2, o método retorna resultados de crescente instabilidade. Contudo, ele é sensivelmente mais rápido caso lambda seja menor que 1/2

# %%
import numpy as np
import math

def funcBase(x):
    return math.sin(math.pi*x) + (x-x**2)     #funcao base fixada

# %%
def diferencasAvancadas(gamma = 1, L = 1, K = 0.005, H = 0.01, numIter = 5):
 
    '''
    Essa funcao aproxima a solução de uma equação diferencial de segundo grau, uma equação do calor,
    atravéz do método das diferenças finitas avançadas, utilizando uma multiplicação de matriz
    manual simplificada, já que a maioria dos elementos da matriz tridiagonal usada são nulos.
    Esse método tende a ser instável, especialmente quando lambda = gamma*k/h^2 >= 1/2 .
    '''
    
    size = (L/(H))-1                                     # inicializa o tamanho da matriz e do vetor de soluções

    uJ = []                                              # inicializa o vetor de solucoes
    saida = []                                           # inicializa o vetor de vetores da saida
    
    for cont in range(1, int(size)+1):                   # este 'for' roda size vezes, exceto em zero para inicializar
        uJ.append(funcBase(cont*H))                      # 'u(0)', um vetor com "size" elementos, no vetor de solucoes
    saida.append(uJ)                                     # insere esta solucao na posicao '0' do vetor de saida
    
    lmbda = gamma*K/(H**2)                               # inicializa o lambda
    
    for contIter in range(0, numIter):
        contH = 0                                        # inicializa o contador de linhas
        uPlus = []                                       # reinicia o vetor que guarda os elementos do novo vetor U(j+1)

        uTemp = 0                                        # variavel temporaria que guarda cada elemento
                                                         # a ser colocado no vetor U(j+1)

        uTemp += ((1-(2*lmbda))*uJ[0]) + 2*K             # esse bloco faz a multiplicacao do vetor U(j)
        uTemp += (lmbda*uJ[1]) + 2*K                     # pela primeira linha da matriz, sem o primeiro "lambda"
        uPlus.append(uTemp)                              # os resultados somados viram o primeiro elemento do vetor U(J+1)

        for contH in range(1, (int(size)-1)):            # esse for faz as linhas 0 < n < size

            uTemp = 0                                    # Reinicia a variavel temporaria

            uTemp += (lmbda*uJ[contH-1]) + 2*K           # esse bloco faz a multiplicacao do vetor U(j) pela linha
            uTemp += ((1-(2*lmbda))*uJ[contH]) + 2*K     # "contH" da matriz, com os tres elementos da tridiagonal
            uTemp += (lmbda*uJ[contH+1]) + 2*K           # os resultados somados viram o primeiro elemento do vetor U(J+1)
            uPlus.append(uTemp)

        uTemp = 0                                        # Reinicia a variavel temporaria

        uTemp += (lmbda*uJ[int(size)-2]) + 2*K           # esse bloco faz a multiplicacao do vetor U(j)
        uTemp += ((1-(2*lmbda))*uJ[int(size)-1]) + 2*K   # pela primeira linha da matriz, sem o segundo "lambda"
        uPlus.append(uTemp)                              # os resultados somados viram o primeiro elemento do vetor U(J+1)

        uJ = uPlus                                       # substitui o vetor U(j) pelo novo vetor
        
        plt.plot( uJ, 'b-')                              #
        plt.title("Solucoes em tempo t = %f"% (K))         # imprime um grafico para
        plt.ylabel('Solucao')                            # cada vetor de solucao 'uJ'
        plt.show()                                       #
        
        saida.append(uJ)                                 # insere o vetor de solucao atual no vetor de saida
        
    saidaArray = np.array(saida)
    for i in range(0, saidaArray.size):
        print(saidaArray[i])                                   # imprime o vetor de saida
        print

# %%
diferencasAvancadas(1, 1, 0.000001, 0.01, 5)  #lambda = 1/100 < 1/2
# Out:
# [ 0.04131076  0.08239052  0.12320831  0.16373323  0.20393447  0.24378131
#   0.28324324  0.32228989  0.36089111  0.39901699  0.43663792  0.47372455
#   0.51024789  0.54617929  0.5814905   0.61615367  0.65014142  0.68342679
#   0.71598338  0.74778525  0.77880705  0.80902399  0.83841187  0.86694711
#   0.89460678  0.92136863  0.94721107  0.97211324  0.99605501  1.01901699
#   1.04098057  1.06192793  1.08184203  1.10070668  1.11850652  1.13522705
#   1.15085463  1.16537649  1.17878077  1.19105652  1.20219369  1.21218316
#   1.22101676  1.22868725  1.23518834  1.2405147   1.24466196  1.24762673
#   1.24940656  1.25        1.24940656  1.24762673  1.24466196  1.2405147
#   1.23518834  1.22868725  1.22101676  1.21218316  1.20219369  1.19105652
#   1.17878077  1.16537649  1.15085463  1.13522705  1.11850652  1.10070668
#   1.08184203  1.06192793  1.04098057  1.01901699  0.99605501  0.97211324
#   0.94721107  0.92136863  0.89460678  0.86694711  0.83841187  0.80902399
# ...

# %%
diferencasAvancadas(1, 1, 0.00001, 0.01, 5) #lambda = 1/10 < 1/2

# %%
diferencasAvancadas(1, 1, 0.00005, 0.01, 5)  #lambda = 1/2 = 1/2

# %%
diferencasAvancadas(1, 1, 0.001, 0.01, 5)   #lambda = 10 > 1/2

# %%
diferencasAvancadas(1, 1, 0.01, 0.01, 5)   #lambda = 100 > 1/2

# %%
def diferencasAvancadas_strings (L, dt, dl, gamma=1, numIter=5, coefLinearNaDiff=2):
    alpha = dt/(dl**2)
    size = int(L//dl - 1)
    A = np.zeros([size, size])
    np.fill_diagonal(A, 1 + 2*alpha)
    np.fill_diagonal(A[1:,:-1], 0-alpha)
    np.fill_diagonal(A[:-1, 1:], 0-alpha)
    
    print "Matriz A:", A
    
    u = []
    uk = []
    for i in range(size):             
        uk.append(funcBase(i*dl))                
    u.append(uk)
    
    
    for i in range (numIter):
        uK = (np.dot(A, uk) + 2*alpha).tolist()
        u.append(uK)
        
        plt.plot(np.arange(0,98),uK, 'b-')                              #
        plt.title("Solucoes em tempo t = %f"% (K))        # imprime um grafico para
        plt.ylabel('Solucao')                            # cada vetor de solucao 'uJ'
        plt.show()           
        
    return u

# %%
print diferencasAvancadas_strings(1, 0.00001, 0.01)  #lambda = 1/10 < 1/2

# %%
def tridiag(a, b, c, k1=-1, k2=0, k3=1):
    '''
    Esta função cria uma matriz tridiagonal a partir de três vetores, usando a função np.diag da biblioteca NumPy
    '''
    return np.diag(a, k1) + np.diag(b, k2) + np.diag(c, k3)

# %%
def diferencasAvancadas2(gamma = 1, L = 1, K = 0.005, H = 0.01, numIter = 5):
    
    '''
    Esta funcao aproxima a solução de uma equação diferencial de segundo grau, uma equação do calor,
    atravéz do método das diferenças finitas avançadas, utilizando a multiplicação de matriz da biblioteca NumPy.
    Este método tende a ser instável, especialmente quando lambda = gamma*k/h^2 >= 1/2 .
    '''

    size = (L/(H))-1                               # inicializa o tamanho da matriz e do vetor de soluções

    uJ = []                                        # inicializa o vetor de solucoes
    saida = []                                     # inicializa o vetor de vetores da saida
    
    for cont in range(1, int(size)+1):             # este 'for' roda size vezes, exceto em zero para inicializar
        uJ.append(funcBase(cont*H))                # 'u(0)', um vetor com "size" elementos, no vetor de solucoes
    saida.append(uJ)                               # insere esta solucao na posicao '0' do vetor de saida
    
    lmbda = gamma*K/(H**2)                         # inicializa o lambda
    
    matrizA = []                                   #
    menosL = []                                    # inicializa os vetores auxiliares para fazer a tridiagonal
    umMaisL = []                                   #
    
    for cont in range(0, int(size)-1):             #
        menosL.append(-1*lmbda)                    # preenche os vetores auxiliares com
    for cont in range(0, int(size)):               # os elementos usados na tridiagonal
        umMaisL.append(1+(2*lmbda))                #
    
    matrizA = tridiag(menosL, umMaisL, menosL)     # faz a matriz tridiagonal usando a funcao tridiag
    
    for contIter in range(0, numIter):            # este 'for' roda para cada iteracao requerida
        uPlus = []                                 # cria/anula o vetor que contem a nova solucao
        
        for cont in range(0, int(size)):           # preenche o vetor da nova solucao com
            uPlus.append(uJ[cont]+2*K)             # valores dados pela formula do metodo
            
        uPlus = np.dot(matrizA, uPlus)             # faz a multiplicacao da matriz com o vetor

        uJ = uPlus                                 # substitui o vetor U(j) pelo novo vetor
        
        plt.plot( uJ, 'b-')                        #
        plt.title("Solucoes em tempo t = %f"% (K))   # imprime um grafico para
        plt.ylabel('Solucao')                      # cada vetor de solucao 'uJ'
        plt.show()                                 #
        
        saida.append(uJ)                           # insere o vetor de solucao atual no vetor de saida
        
    saidaArray = np.array(saida)
    for i in range(0, saidaArray.size):
        print(saidaArray[i])                                   # imprime o vetor de saida
        print

# %%
diferencasAvancadas2(1, 1, 0.000001, 0.01, 5)  #lambda = 1/100 < 1/2

# %%
diferencasAvancadas2(1, 1, 0.00001, 0.01, 5) #lambda = 1/10 < 1/2

# %%
diferencasAvancadas2(1, 1, 0.00005, 0.01, 5)  #lambda = 1/2 = 1/2

# %%
diferencasAvancadas2(1, 1, 0.001, 0.01, 5)   #lambda = 10 > 1/2

# %%
diferencasAvancadas2(1, 1, 0.01, 0.01, 5)   #lambda = 100 > 1/2

# %% [markdown]
# #Método da Diferenças Finitas Atrasadas
#
# Este método utiliza um sistema linear para encontrar o novo veotor u(j) a partir de um vetor u(j-1). Foram implementados dois métodos para resolver esses sistemas, o Método de Guass-Seidel e o Método de Fatoração LU, que podem ser escolhidos na entrada.
#
# Note que quando o lambda (gamma.k/h²) é maior que 1/2, o método permanece estável. Contudo, ele é sensivelmente mais lento que o método anterior, devido à resolução dos sistemas lineares.

# %%
def diferencasAtrasadas (gamma = 1, L = 1, K = 0.0005, H = 0.001, numIter = 5, tipoSis = "gauss"):
    
    '''
    Esta funcao aproxima a solução de uma equação diferencial de segundo grau, uma equação do calor,
    atravéz do método das diferenças finitas atrasadas. Este método é sempre estável, mas requer a
    resolução de um sistema linear. Aqui são usados os métodos de Gauss-Seidel e fatoração LU.
    '''

    size = (L/(H))-1                                # inicializa o tamanho da matriz e do vetor de soluções

    uJ = []                                         # inicializa o vetor de solucoes
    saida = []                                      # inicializa o vetor de vetores da saida
    
    for cont in range(1, int(size)+1):              # este 'for' roda size vezes, exceto em zero para inicializar
        uJ.append(funcBase(cont*H))                 # 'u(0)', um vetor com "size" elementos, no vetor de solucoes
    saida.append(uJ)                                # insere esta solucao na posicao '0' do vetor de saida
    
    lmbda = gamma*K/(H**2)                          # inicializa o lambda
    
    matrizA = []                                    #
    menosL = []                                     # inicializa os vetores auxiliares para fazer a tridiagonal
    umMaisL = []                                    #
    
    for cont in range(0, int(size)-1):              #
        menosL.append(-1*lmbda)                     # preenche os vetores auxiliares com
    for cont in range(0, int(size)):                # os elementos usados na tridiagonal
        umMaisL.append(1+(2*lmbda))                 #
    
    matrizA = tridiag(menosL, umMaisL, menosL)      # faz a matriz tridiagonal usando a funcao tridiag
    
    for contIter in range(0, numIter):              # este 'for' roda para cada iteracao requerida
        uPlus = []                                  # cria/anula o vetor que contem a nova solucao
        
        for cont in range(0, int(size)):            # preenche o vetor da nova solucao com
            uPlus.append(uJ[cont]+2*K)              # valores dados pela formula do metodo
            
        uPlusArray = np.array(uPlus)                # transforma a lista uPlus em um array padrao da biblioteca NumPy
        
        if tipoSis == 'gauss':                      #
            uJ = gaussSeidel(matrizA, uPlusArray)   # roda o metodo de resolucao de sistema
        elif tipoSis == 'lu':                       # linear requerido pelo parametro de entrada
            uJ = linearSolve(matrizA, uPlusArray)   #
        else: print("Erro, metodo de solucao de sistema linear invalido!")
            
        
            
        plt.plot( uJ, 'b-')                         #
        plt.title("Solucoes em tempo t = %f"% (K))    # imprime um grafico para
        plt.ylabel('Solucao')                       # cada vetor de solucao 'uJ'
        plt.show()                                  #
        
        saida.append(uJ)                            # insere o vetor de solucao atual no vetor de saida
        
    saidaArray = np.array(saida)
    for i in range(0, saidaArray.size):
        print(saidaArray[i])                                   # imprime o vetor de saida
        print

# %%
diferencasAtrasadas(1, 1, 0.000001, 0.01, 5)  #lambda = 1/100 < 1/2

# %%
diferencasAtrasadas(1, 1, 0.00001, 0.01, 5) #lambda = 1/10 < 1/2

# %%
diferencasAtrasadas(1, 1, 0.00005, 0.01, 5)  #lambda = 1/2 = 1/2

# %%
diferencasAtrasadas(1, 1, 0.001, 0.01, 5)   #lambda = 10 > 1/2

# %%
diferencasAtrasadas(1, 1, 0.01, 0.01, 5)   #lambda = 100 > 1/2
